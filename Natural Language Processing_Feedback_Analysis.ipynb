# %%
import nltk
messages = [line.rstrip() for line in open('/Users/hongpingwu/Midterm Feedback Form - Voxaer (Responses) - Form Responses 1.csv')]
# print(len(messages))
messages 
# print(type(messages))
# Out:
# ['Timestamp,Do you play this genre of game (Rhythm Game)?,What were some of the easier parts of the gameplay to understand?,What were some of the harder parts of gameplay to understand/use?,How hard do you think the AI is?,What aspects of the game would you be interested in playing more of?,What parts of the game could be improved - and why?',
#  '6/30/2022 18:12:34,Yes,easy instructions and nice UI,understand what those icons mean,A little too hard!,the music,I think it is great',
#  '6/30/2022 18:50:42,No,the fighting aspect where it is two people trying to bet each other,"how the constant clicking creates differences in the players, how it is not just the same thing each player is doing.",Balanced. I like this AI!,"the fighting, It didnt really do much with the music. ",randomness or more skill added to the game.',
#  '6/30/2022 18:53:28,Yes,different attacks with different arrows,the counter attacks and skills against each other,Balanced. I like this AI!,Great sounds,There are no differences between different perfect degrees in terms of damages or other effects.',
#  '6/30/2022 18:54:28,yes,"the function of each W A S D, and the way to play this game",what are the difference of the 2 kinds of attack,Easy.,more ways to protect/ attack,maybe explain more about how 2 different functions would work together (eg. magical attack to physical shield)',
#  '6/30/2022 18:55:10,No,Simple game - easy to know rhythm,n/a,Easy.,"I would be interested in adding a typing game aspect to this rhythm game. The game is very simple, and typing words at different speeds would be a way to make it more interesting / challenging","I think the game would benefit by adding music notes (whole notes, half notes, quarter notes, eighth notes, sixteen notes ,etc..) at different tempos (ex: 60bpm, 80bpm, etc..)"',
#  '6/30/2022 18:55:27,No,just to click wasd,Its easy ,Balanced. I like this AI!,With AI,add some more functionalities like movements of players. Players can come closer or move away from each other.',
#  '6/30/2022 18:56:10,Not really but I am open to these types of games,"It was very intuitive that I have to hit different keys to either attack, defend, or heal.","I don\'t understand the strategy behind the game, can I just hit attack all game and win?",Balanced. I like this AI!,I\'d be interested in if the platforms coming down maybe came in different angles such as guitar hero.,I think there should be more user strategy such as moving around instead of the entire premise of the game being hitting keys and looking at what the other user is hitting.',
#  '6/30/2022 18:57:01,yes,"collect nodes, make combinations",What happens if I don\'t make correct attack patterns correctly,Balanced. I like this AI!,"listening to the music, and makes the nodes come with the music better",music seemss unnecsssary here',
#  '6/30/2022 18:57:47,Yes,Catching the rhythm is not hard.,Thinking the strategy to defeat the other.,Easy.,The music and the way you can play with your friend(yes I have friend to play with XD),More skills to use and more animations of the two guys fight each other.',
#  '6/30/2022 18:58:51,No,key board functions,Hit point could be more clear,Balanced. I like this AI!,different combos of not necessarily 3 of the same ,"Clearer hit point, it\'s overlapped with the combo area "',
#  '6/30/2022 18:59:15,Yes,When to hit buttons,"How exactly rhythm matters, why there are 3 slots if you can\'t mix and match options, why there is physical defend but not magical defend, why not just spam attack",Easy.,The rock paper scissors system,"Combat feels very unbalanced, buttons can be spammed with no punishment, it\'s not very clear how to strategize"',
#  '6/30/2022 18:59:25,No,The Fighting symbols are nice,I did not understand where to align the boxes as they came down.,Way too easy.,More attacking variations!,"More interesting symbols would be nice, otherwise it gets repetitive. "',
#  '6/30/2022 18:59:37,Yes,"There were ways to shield attack, heal, and magic penetration for shield. We need to land it on the correct beat to make the most from getting the 3 pairs of elements",I thought that the health bar was at first the place we need to land the blocks on (specifically the middle of the health bar) to get a perfect score. Maybe you could put the health bar on top instead on the side where the block notes are passing so it wont confuse people thinking it is the hit box,Balanced. I like this AI!,It would be interesting in an advance setting if combinations of element would create some sort of ultimate combo or something instead of just three of the same elements repeating,putting the health bar away from the route of the falling blocks so that people wont confuse it as the hit box for perfect notes',
#  '6/30/2022 18:59:44,No,Easy to understand controls and tutorial makes it easy to understand how to attack,Understanding the differences in the attacks that can be used. I just started using the same attack over and over again and kept winning even against the hard AI. Wasn\'t sure why I should use any of the other attacks.,Easy.,The rhythm part of the game is fun and I would be interested in continuing to play that.,"I didn\'t really have much of a strategy while playing, I just kept hitting the \'D\' key every time and was beating the hard AI. I think if the strategy was more important then it would be more fun."',
#  '6/30/2022 18:59:56,Yes,Keys to use,what timing or position to make perfect,Easy.,different combos.,"To clarify how to achieve a perfect, you can add a different bright color when it\'s ""perfect""."',
#  '6/30/2022 19:00:02,No,Pressing keys to collect three in a row to complete an action,The strategic aspects as it was hard to focus on the other player leading to button spam and guessing what the best move would be,Maybe could use better balancing between the levels,Being on beat is satisfying but I wish I had more strategy to it,Tightening the rhythm aspect to correlate to if the player can match the beat they will be rewarded with something rather than just being able to spam buttons.',
#  '6/30/2022 19:00:07,Yes,The Mechanics is easy.,It hard to end the game. It takes too long.,A little too hard!,hard part.,I think maybe the number of nodes could be changed.',
#  '6/30/2022 19:00:35,I haven\'t played that many rythme games before,To understand how the combos worked,Seeing what the other player is doing. The particle effects made it really hard what was going on. ,Balanced. I like this AI!,"I think different combos would help, because it feels like im spamming my keys even though im trying to combo.","I think the particle effects need to be clearer. Also, moving the 2 characters away from each other would help as too much stuff is happening at the game time."',
#  '6/30/2022 19:01:16,Yes,Beat on rhythm,The strategy among four types,Way too easy.,Rhythm game itself,"The strategy among four types is imbalance, the decent/prefect/great make no difference"',
#  '6/30/2022 19:01:22,yes,how to hit the notes,I wasn\'t really sure what the difference between the physical and magical attack was,Easy.,"More songs options, because this game is fun",explaining what the effects of the different elements are',
#  '6/30/2022 19:01:41,yes,how to attack,the tutorial UI is kind of different from the actual gameplay. ,Way too easy.,"more skill sets with different combination of keys, such as d->s->a","AI is too easy, even in the hard mode. The physical defense seems to be unworthy to use. "',
#  '6/30/2022 19:01:43,Yes,"Two players need to play at the same time, or simply just play it with AI",Is there any difference of the four direction button? ,Way too easy.,How to win fast?,Maybe two of the players can get closer ?',
#  '6/30/2022 19:01:51,Not much,The different types of moves and how to achieve each is easy to understand.,None of it was really difficult to understand.,Way too easy.,I would be interested in trying the game with more different types of rhythms.,"In the tutorial, it seems that the tutorials are popping up over the game while the game is still running. This is confusing and seems to make the tutorial more difficult to play. Stopping the game during the tutorial popups would help with this."',
#  '6/30/2022 19:02:30,No,two players needed and how to collect skill,how to win ,Balanced. I like this AI!,more interactive between two players,more interactive between two players',
#  '6/30/2022 19:02:31,Sometimes,You need to hit some keys at certain times,"The number of options. Magic is objectively the best option and whoever gains even the slightest advantage is most likely to win. You can just spam magic. Spamming seems an easier strategy than actually trying to time your key presses to get ""perfect""",No AI. It\'s a 2 player game,Slower songs with better visuals to indicate proper timing,"Visuals. Proper timing was hard to discern. The ""rock paper scissors"" system of keys could be vastly improved. Currently magic seems to be the strongest ability"',
#  '6/30/2022 19:03:18,yes,the controls were easier to understand,the difference between different attacks and who does the most damage,Balanced. I like this AI!,I would love to play new levels,"I won the game by spamming a particular key without playing the rhythm. Is there a way so that you can prevent that like adding a penalty if you miss the beat multiple times',
#  '"',
#  '6/30/2022 19:04:05,yes,enter keys,understand when to press which key,Balanced. I like this AI!,attacking effects,maybe the background',
#  '6/30/2022 19:04:06,No,How each different type of move counters another move.,How long the defense spell lasts; and when exactly to press the button to get a hit on the falling object.,Easy.,The strategy aspect of figuring out what skill to use to counter the other player.,A longer explanation for each skill in the tutorial; and an incentive for getting a perfect hit on a block versus just a good hit.',
#  '6/30/2022 19:04:21,Yes,Mechanics,I can\'t get how to win and how to end the game.,Easy.,I am interested in the music part.,"The tutorial and mechanics, because it is hard for me to understand and I don\'t know how to win the game."',
#  '6/30/2022 19:05:17,Yes,2 players need to fight with each other,when player need to change to other key codes for winning this game. It seems when should attach or protect are all assigned by the game.,A little too hard!,"Trying to beat the enemy. Also, I like the game can be 2 players game, or 1 player play with AI.","If need users randomly pressed the 4 key codes for different functions, it might add more fun for the game. "',
#  '6/30/2022 19:05:45,Yes,Instructions are clear,It is hard find where to start with AI. It seems I can start after I enter the game. I think it can be improved,A little too hard!,I like the music,"1. It is hard find where to start with AI. It seems I can start after I enter the game. I think it can be improved',
#  '2. when I miss pressing, or pressing error, there is no penalty, which meanings I can always press"',
#  '6/30/2022 19:05:54,No,press the key before a block arrives the ground.,How to press the key in rhythm to get the move,Easy.,more combination of magic + physical attack,The rhythm algorithm should improve.',
#  '6/30/2022 19:06:08,Yes,Press the key to match the beat,when to press the key,Easy.,Againest differnt AI,The music cube should generate by rhythm.',
#  '6/30/2022 19:06:10,Yes,"pressing W/A/S/D to consume the block, attack/Heal/Magic and Defense concepts and HP concept",did not clearly understand the mapping between W/S/D/A and power. I deduced it by playing multiple times.,Balanced. I like this AI!,More levels and different levels. ,"Tutorial level was hard to understand at first glance.Difference between magic attack and physical attack.',
#  '"',
#  '6/30/2022 19:06:39,no,it\'s clear to use atk/def/heal,"it took me a while to figure out how to enable ai.',
#  'and I\'m not too sure, what\'s the great/perfect timing affecting the game.",Easy.,"more music, stronger AI","it looks like I could just easily win the ai if I keep attacking? it probably needs more strategy. if I should follow some pattern strictly, instead keep attacking as i want."',
#  '6/30/2022 19:07:19,No,The health aspect and that notes were coming that were supposed to be timed hits. Right at the start I knew that the two players were playing against each other by matching the notes. ,"In the tutorial I was unaware of the actual keys to use, but was later shown in the main game which keys were used. Since there are various elements to the game such as magic and shield it was difficult to adapt as a beginner. It became more apparent which attacks/defense were more useful throughout the game",Easy.,"Player vs AI, but more fighting elements. There are already pros and cons of each type of combat/defense system, but maybe more strategy can be added to it. ",Initial tutorial demonstrating all the keys that are suppose to be used. An indicator in tutorial showing I hit the notes.',
#  '6/30/2022 19:08:52,no,attack and defense mechanism,limited time in making the decision by considering multiple factors like opponents score,A little too hard!,distribution into more levels,option for selecting sharper knives etc',
#  '6/30/2022 19:09:46,Not yet,Using skills to cause damage to opponent,Use which combination to get specific skill,Balanced. I like this AI!,The animation of different skills,I wonder if players can move the characters',
#  '6/30/2022 19:10:19,yes,rhythm game is easy to understand and the instruction is clear,none,Easy.,enjoy different songs,lose hp or clean up the array when miss or hit at a wrong timing',
#  '6/30/2022 19:10:20,No,The attack and defense mechanism was easier to understand.,scoring was something hard to understand,Balanced. I like this AI!,the fighting part of the game is something is interesting.,I feel more easier interactive UI will be something good to work on because initially it was confusing for players to understand there movements.',
#  '6/30/2022 19:11:00,No,The controls of the game,How exactly to use the shields and their purpose.,Easy.,More skills,Maybe an explanation of shields are to be used.',
#  '6/30/2022 19:13:33,no,catch the white block,I think everything is not hard,Balanced. I like this AI!,"if you don\'t miss the block for several times, you can get some reward",you can exit from tutorial (add home button);add some music when you win the game',
#  '6/30/2022 19:13:49,NO,"when to hit the keys, tutorial was clear","Wasn\'t sure of the music notes. I was just checking when the rectangles land on the white line, to press the controls, some learning curve with the controls. ",A little too hard!,Players in action/movement,Single player vs computer would be good to have',
#  '6/30/2022 19:14:43,Yes,"Tutorial was helpful to understand the game, the controls were easy to use. And having the AI for the second player was good.","How different powers work, needed more clarification.",Balanced. I like this AI!,To make more perfect hits. ,May be color code for the powers and store them and to use them when required.',
#  '6/30/2022 19:15:04,"No, I do not play Rhythm Games.",I understood the controls and when I was completing a combo to do a move. ,"I didn\'t understand why I should use each of the four moves, in what situations they\'d be helpful (like why would I pick one attack over another was not clear to me). I didn\'t understand the point of perfect hits versus decent hits with timing. ",Easy.,"I would be interested in more complicated songs visually, maybe if the shape or direction of the dropping blocks changes to fit with the song. ","There was no penalty for spamming buttons. There were some large lulls in the songs for when blocks dropped and I didn\'t quite understand the pattern. I felt locked into a symbol after selecting the first one since then I had to get two more of the same one or it would be invalid. I was hoping maybe there would be a way to store all 4 potential moves (so maybe I could have 2 physical attack, 2 magic attacks both saved up, and then whether I choose to do physical or magic next it\'ll hit and reset that individual counter). "',
#  '6/30/2022 19:15:33,Yes,The overall mechanism and winning conditions.,what happens if I press different keys in a three-press combo.,Balanced. I like this AI!,Key-press on music note.,Maybe more details on what to expect from the game.',
#  "6/30/2022 19:17:17,No,Selecting the tile you want,When to use the different tiles. I didn't feel a need to use the heal since the attack just did more than heal for the same amount of work and I couldn't tell the benefit of the physical def and didn't seem worth the gamble if they chose anything other than physical attack.,Easy.,Playing against friends on more levels,The balance and making the different things more worth it. Potentially allowing you to mix and match and having a bonus for the combo with the same 3",
#  '6/30/2022 19:17:39,Yes,press  w a s d to gain power,"Should have a timer with defend, and heal is less useful than others",Way too easy.,Game music ,"Maybe can add more mana, which makes the game mechanism more fun. For example, with longer sequence(red red blue yellow yellow) can cause severe damage than simple attach"',
#  '6/30/2022 19:17:50,yes,Totally 2 players,Operation is difficult to understand,A little too hard!,art design is cool,"the opreation instruction should be improved, and the blood could loss quickly."',
#  '6/30/2022 19:19:08,This was my first time playing a rhythm game.,It was easy to understand that we want to hit the key when yellow box just touches the ground.,"It took me some time to figure out that I can chose my move (heal/defense/attack, etc.) Also when I chose to attack, the visuals of the attack (Red colored sword swings)are shown on the opponents side. In the beginning I was not sure if my attack was getting fired correctly.",A little too hard!,"I would love to play with more music pieces where the rhythms vary from very slow to fast, also it would be fun to play with a very well known song where I know how fast/slow beats are going to be, which will help me to device a strategy (e.g. attack when fast beats, heal when slow beats, etc.)",I found the defense and attack moves a bit tough to differentiate while playing (because of both having Red color flash). It would be great if you could use different color for these two (like you have already for heal).',
#  '6/30/2022 19:21:35,yes,skills,the rhythm can be more intense,Balanced. I like this AI!,skills ,the introductions',
#  '6/30/2022 19:23:26,Yes,"After tutorial, I can understand how to make attack.",it\'s hard to find the matching timing for some blocks.,Easy.,"Fighting Mechanism, that\'s pretty much fun.","Maybe have more attacking mechanisms, for instance: SSA as a new mechanism, can make this game much more fun, since player needs to consider how to make more effective attack."',
#  '6/30/2022 19:23:47,Yes,Meeting perfect on the music rythm,Looking at opponent\'s attack when focusing on the music and my attacks ,Balanced. I like this AI!,More combination of attacks,"Add character skills, and add more combination of attacks"',
#  '6/30/2022 19:24:39,YES,we can use some special button to create the attack or defense skill.,All things are very good.,Balanced. I like this AI!,the mechanism,"The man may be can have some movement when he use attack ability. (I am not sure it\'s a bug, but my player is always stand there)"',
#  '6/30/2022 19:25:55,No,easy,easy,Easy.,style,design different beats for two players on the same level',
#  '6/30/2022 19:38:45,No,Combos were easy to understand.,It was hard to tell what my opponenet was doing,Easy.,Having different kind of combos instead of combos with the same type of action.,I think the game could use beats the follow songs instead of procedural generation. I wanted to learn the song beats which made it fun.',
#  '6/30/2022 19:44:57,No,Controls and powerups,"Nope, it was smooth sailing",Balanced. I like this AI!,"An expert AI, if possible, would be really cool. Also, customisable player characters could be nice",The gameplay is really good. I love it.',
#  '6/30/2022 19:47:12,Yes,press WASD for different attack/defense,"At first I don\'t know when shall I press key, I don\'t know if I shall press the key while the block is close to the alphabet or close to the ground. ",Easy.,I like Jay Chou.,"More combination of keys to enable different skills, or pressing the key for a period of time to enable new skills etc."',
#  "6/30/2022 19:47:29,Yes,Press the keyboard to hit,The rhythm doesn't match the falling blocks,A little too hard!,Attack,Rhythm",
#  '6/30/2022 19:47:47,Yes,Catching the rhythm. The roles of four different skills.,No.,Balanced. I like this AI!,"Strategies: magic attack can ignore shield, shield can prevent physical attack, physical attack cause higher damage than heal, heal is better than shield.","Heal is not that strong, because it\'s only about 30 hp (lower than all kinds of attack). I think it\'s more balance to make magic attack lower than heal."',
#  '6/30/2022 19:51:27,Yes.,Each attack pattern is pretty easy. (Three consecutive same type),"It would be better if you force players to play the tutorial, because if the players skip the tutorial, they will not understand what to do. The flow of tutorial can be better.",Way too easy.,We can have more pattern.,"1. Currently, ""Perfect"", ""Decent"",  and ""Great"" do not really matter (I believe..?).',
#  "2. I don't think anybody would use Heal if they understand the winning condition.",
#  '3. People cannot exit tutorial when they want to',
#  '4. The game will be more fair if players cannot see other\'s ability sequence"',
#  "6/30/2022 19:52:18,No,collecting the spells,timing took some time to get a hang of it,Easy.,I had to play against AI only but I would like to play against a person,why can't you do multiple things: if I have two physical attacks and a shield shouldn't they all trigger? why do I need three of a kind",
#  "6/30/2022 20:00:00,Yes,How to match the falling down squares ,The meaning of HP and defense in a Rhythm game,A little too hard!,Catch beats,There are endless beats falling down. It's difficult to handle them",
#  '6/30/2022 20:01:29,Yes I do,There are very limited buttons to be used in the gameplay and it is very easy to understand.,The rhymn game hit button and attack button are too closed. It is very hard to know which button was pressed while focusing on the hit button and attack button.,Easy.,I think it is very interesting to have rythmn game mixed with attack and shield power. It is very inspiring and intersting to play.,"I think there could be more interaction between player and AI. All I can see from the screen is two people slashing sword and releasing fire. At first, I am very confused and thought certain bug happened. Maybe some more interactions between player and AI is more preferred."',
#  '6/30/2022 20:13:04,yes,useer controls,Game play is pretty clear,Way too hard!,using simultaneous power ups,"I could easily spam attack and win the game, probably you can have cooldown time after using attack or magic."',
#  '6/30/2022 20:13:20,Yes. but not a lot ,"The UI design is good. And the idea of this game, combing the strategy and rhythm game together.",it\'s kind of hard to understand that you can decide the attack method. ,Balanced. I like this AI!,I really like the AI. could play the game alone.,"1. If I add the health all the time, there\'s no win or lose in the game. (I think maybe add some cool down time for the skills. make sure players can use all the button.)"',
#  "6/30/2022 20:21:03,Sometimes,Player movement and mechanics,Didn't understand the magic attack very well,Balanced. I like this AI!,Some suggestions for user prompts,Magic attacks - does not come intuitively",
#  '6/30/2022 20:22:02,No not much,The concept that we are trying to kill our opponent! And the controls,"The usage of different weapons was hard to grasp, in the sense, when to use what",Balanced. I like this AI!,Find usecases of the weapons more effectively while playing the game,Tutorials I felt need an improvement. The game as such was novel and exciting in my game experience.',
#  "6/30/2022 20:30:13,yes,how to get the powerups through beat,beats didn't exactly match with the song,Way too easy.,have more songs,have the beats match more closely with the song playing",
#  '6/30/2022 20:34:29,Not regularly,The easier parts of the game was understanding which buttons to click. I think the visual indicator for the UI was definitely necessary and helped me understand that I needed to click the A button or the U button without watching the trailer. The tutorial text was also good. ,The harder part of the game was when to click the button to get the power ups. At first I was spamming the buttons then when the white bar matches the brown power up box then along with the beat. I think a visual indicator like a red border outline for the brown box can help teach the user when to tap the buttons in a more visual sense in addition to the tutorial.,Balanced. I like this AI!,Having different power ups and add ons. I think the defense and offense parts of the game were very balanced. If there were also different combos for more powerful moves that would also be interesting,"I think the visual cues would be a help. Visual cues for when to tap the buttons to gain power ups. This wouldn\'t be replacing the tutorial but like the professor said in class, players sometimes do no prefer to read and rely on a more fluid and intuitive game play. I think adding a visual cue to indicate when to tap the button for the power up and another button to use the to attack the opponent would be good.  "',
#  '6/30/2022 20:36:56,No,Basic concept easy to understand,What control to be used to catch the white block,Easy.,Collecting different types of blocks,Tutorials',
#  '6/30/2022 20:52:53,no,the motive of the game,everything was easy,A little too hard!,more thinking other that just hitting beats ,have other aspects to the game like avoid some beats',
#  '7/1/2022 8:00:18,Yes,Get three same patterns to have one combos. Press buttons with the rhythm.,Which combo to choose.,Easy.,The rhythms part. ,Add some animations or sounds when you get a perfect hit',
#  '7/1/2022 13:18:27,Yes,Clear tutorials.,It is hard to hit every element.,Balanced. I like this AI!,The song is good.,Improve game texture qualities and the UI.',
#  "7/3/2022 15:35:08,Yes,Press keys to match the rhythm,I didn't see difference between great and perfect,Easy.,No,Great and perfect hit are not different",
#  '7/5/2022 14:33:43,No,The controls,None,Balanced. I like this AI!,More levels,The animations for the characters',
#  '7/5/2022 14:43:11,No,The controls,None,Balanced. I like this AI!,More levels,More animations for the players',
#  '7/5/2022 17:16:08,yes,hit the box and accumlate the element,What is the usage of different parttern,Easy.,Hit the key buttom with the rhythm and transfer it to the power of the man,"The music is not appropraite, the rhythm is not quiet right"']

# %% [markdown]
# # Do you play this genre of game (Rhythm Game)?

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
# making dataframe 
df_1 = pd.read_csv("Midterm Feedback Form - Voxaer (Responses) - Form Responses 1.csv") 
# output the dataframe
# df.shape[0]
# df
s=df['Do you play this genre of game (Rhythm Game)?'].str.lower()
df=s.to_frame()
# print(df.shape[0])
# standardize all answers to Yes or No.
df.loc[6,"Do you play this genre of game (Rhythm Game)?"]='no'
df.loc[17,"Do you play this genre of game (Rhythm Game)?"]='no'
df.loc[22,"Do you play this genre of game (Rhythm Game)?"]='no'
df.loc[44,"Do you play this genre of game (Rhythm Game)?"]='no'
df.loc[49,"Do you play this genre of game (Rhythm Game)?"]='no'
df.loc[67,"Do you play this genre of game (Rhythm Game)?"]='no'
df.loc[69,"Do you play this genre of game (Rhythm Game)?"]='no'
df.loc[24,"Do you play this genre of game (Rhythm Game)?"]='yes'
df.loc[37,"Do you play this genre of game (Rhythm Game)?"]='yes'
df.loc[60,"Do you play this genre of game (Rhythm Game)?"]='yes'
df.loc[63,"Do you play this genre of game (Rhythm Game)?"]='yes'
df.loc[65,"Do you play this genre of game (Rhythm Game)?"]='yes'
df.loc[66,"Do you play this genre of game (Rhythm Game)?"]='yes'
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', None)  # or 199
# print(df.shape[0])
df
print(df[(df['Do you play this genre of game (Rhythm Game)?'] == 'yes')].shape[0])
print(df[(df['Do you play this genre of game (Rhythm Game)?'] == 'no')].shape[0])
#visualization
y = np.array([45, 33])
mylabels = ["Yes", "No"]
colors=['orange', 'green']
myexplode = [0.1, 0]
plt.pie(y, labels = mylabels, colors=colors, startangle = 90,explode = myexplode,shadow = True)
plt.legend() 
plt.show()
# Out:
# 45
# 33

# %%
play_or_not=df_1.iloc[:, 1:2]
play_or_not
# Out:
#        Do you play this genre of game (Rhythm Game)?
# 0                                                Yes
# 1                                                 No
# 2                                                Yes
# 3                                                yes
# 4                                                 No
# 5                                                 No
# 6   Not really but I am open to these types of games
# 7                                                yes
# 8                                                Yes
# 9                                                 No
# 10                                               Yes
# 11                                                No
# 12                                               Yes
# 13                                                No
# 14                                               Yes
# 15                                                No
# 16                                               Yes
# 17    I haven't played that many rythme games before
# 18                                               Yes
# 19                                               yes
# 20                                               yes
# 21                                               Yes
# 22                                          Not much
# 23                                                No
# 24                                         Sometimes
# 25                                               yes
# 26                                               yes
# 27                                                No
# 28                                               Yes
# 29                                               Yes
# 30                                               Yes
# 31                                                No
# 32                                               Yes
# 33                                               Yes
# 34                                                no
# 35                                                No
# 36                                                no
# 37                                           Not yet
# 38                                               yes
# 39                                                No
# 40                                                No
# 41                                                no
# 42                                                NO
# 43                                               Yes
# 44                   No, I do not play Rhythm Games.
# 45                                               Yes
# 46                                                No
# 47                                               Yes
# 48                                               yes
# 49     This was my first time playing a rhythm game.
# 50                                               yes
# 51                                               Yes
# 52                                               Yes
# 53                                               YES
# 54                                                No
# 55                                                No
# 56                                                No
# 57                                               Yes
# 58                                               Yes
# 59                                               Yes
# 60                                              Yes.
# 61                                                No
# 62                                               Yes
# 63                                          Yes I do
# 64                                               yes
# 65                               Yes. but not a lot
# 66                                         Sometimes
# 67                                       No not much
# 68                                               yes
# 69                                     Not regularly
# 70                                                No
# 71                                                no
# 72                                               Yes
# 73                                               Yes
# 74                                               Yes
# 75                                                No
# 76                                                No
# 77                                               yes

# %% [markdown]
# # What were some of the easier parts of the gameplay to understand?

# %%
easier_parts=df_1.iloc[:, 2:3]

result_easier_parts=easier_parts.to_string().strip().replace("\n", "")
result_easier_parts= ''.join([i for i in result_easier_parts if not i.isdigit()])
stop_words_ = set(stopwords.words('english'))
# print(stop_words)
word_tokens_ = word_tokenize(result_easier_parts)
filtered_sentence_ = [w for w in word_tokens_ if not w.lower() in stop_words_]
# filtered_sentence_

#remove punctuations
words_without_punct = [''.join(letter for letter in i if letter not in string.punctuation) for i in filtered_sentence_]

processed_words_=[]
for i in words_without_punct:
    j = i.replace(' ','')
    processed_words_.append(j)

while("" in processed_words_) :
    processed_words_.remove("")
# print(processed_words_)

meaningless_words_=['understand','What','trying','could', 'I', 'think','There','get','used','easier','D','s', 'Is','To','maybe','Maybe','This','s','Also','ca', 'nt','like'
                  'would','like','A','player','difficult','would','really','took','It','use','hard','gets','know','harder','s','easy','need','All','first',
                    'different','The','levels','better','nt','seems','game','nt','It','I','An','even','eg','want','wanted']
for i in list(processed_words_): 
    if i in meaningless_words_:
        processed_words_.remove(i)
# print(processed_words_)


# df = pd.DataFrame (processed_words_, columns = ['What were some of the easier parts of the gameplay to understand?'])
# # print(df)
# counts = df['What were some of the easier parts of the gameplay to understand?'].value_counts().to_dict()
# print(counts)

frequency_word_ = nltk.FreqDist(processed_words_)
print(frequency_word_.most_common(40))



s_=" ".join(str(g) for g in processed_words_)
sia_ = SentimentIntensityAnalyzer()
print(sia_.polarity_scores(s_))


df__ = pd.DataFrame(frequency_word_.most_common(40), columns =['Easier parts', 'Mentioned Word Frequency'])
df__
# Out:
# [('attack', 9), ('controls', 9), ('rhythm', 8), ('hit', 8), ('keys', 6), ('players', 5), ('key', 4), ('buttons', 4), ('tutorial', 4), ('clear', 4), ('Press', 4), ('UI', 3), ('two', 3), ('play', 3), ('click', 3), ('collect', 3), ('make', 3), ('beat', 3), ('notes', 3), ('move', 3), ('press', 3), ('block', 3), ('match', 3), ('concept', 3), ('defense', 3), ('mechanism', 3), ('skills', 3), ('good', 3), ('button', 3), ('parts', 2), ('gameplay', 2), ('nice', 2), ('aspect', 2), ('heal', 2), ('Catching', 2), ('shield', 2), ('three', 2), ('Mechanics', 2), ('combos', 2), ('AI', 2)]
# {'neg': 0.154, 'neu': 0.657, 'pos': 0.188, 'compound': 0.7783}
#    Easier parts  Mentioned Word Frequency
# 0        attack                         9
# 1      controls                         9
# 2        rhythm                         8
# 3           hit                         8
# 4          keys                         6
# 5       players                         5
# 6           key                         4
# 7       buttons                         4
# 8      tutorial                         4
# 9         clear                         4
# 10        Press                         4
# 11           UI                         3
# 12          two                         3
# 13         play                         3
# 14        click                         3
# 15      collect                         3
# 16         make                         3
# 17         beat                         3
# 18        notes                         3
# 19         move                         3
# 20        press                         3
# 21        block                         3
# 22        match                         3
# 23      concept                         3
# 24      defense                         3
# 25    mechanism                         3
# 26       skills                         3
# 27         good                         3
# 28       button                         3
# 29        parts                         2
# 30     gameplay                         2
# 31         nice                         2
# 32       aspect                         2
# 33         heal                         2
# 34     Catching                         2
# 35       shield                         2
# 36        three                         2
# 37    Mechanics                         2
# 38       combos                         2
# 39           AI                         2

# %% [markdown]
# # What were some of the harder parts of gameplay to understand/use?

# %%
harder_parts=df_1.iloc[:, 3:4]

result_harder_parts=harder_parts.to_string().strip().replace("\n", "")
result_harder_parts = ''.join([i for i in result_harder_parts if not i.isdigit()])
stop_words_ = set(stopwords.words('english'))
# print(stop_words)
word_tokens_ = word_tokenize(result_harder_parts)
filtered_sentence_ = [w for w in word_tokens_ if not w.lower() in stop_words_]
# filtered_sentence_

#remove punctuations
words_without_punct = [''.join(letter for letter in i if letter not in string.punctuation) for i in filtered_sentence_]

processed_words_=[]
for i in words_without_punct:
    j = i.replace(' ','')
    processed_words_.append(j)

while("" in processed_words_) :
    processed_words_.remove("")
# print(processed_words_)

,
meaningless_words_=['understand','What','sure','could', 'I', 'think','There','get','used','D','s', 'Is','To','maybe','Maybe','This','s','Also','ca', 'nt','like'
                  'would','like','A','player','difficult','would','really','took','It','use','hard','gets','know','harder','s','easy','need','All','first',
                    'different','The','levels','better','nt','seems','game','nt','It','I','An','even','eg','want','wanted']
for i in list(processed_words_): 
    if i in meaningless_words_:
        processed_words_.remove(i)
# print(processed_words_)


# df = pd.DataFrame (processed_words_, columns = ['What were some of the harder parts of gameplay to understand/use?¶'])
# # print(df)
# counts = df['What were some of the harder parts of gameplay to understand/use?¶'].value_counts().to_dict()
# print(counts)

frequency_word_ = nltk.FreqDist(processed_words_)
print(frequency_word_.most_common(40))

s_=" ".join(str(g) for g in processed_words_)
sia_ = SentimentIntensityAnalyzer()
print(sia_.polarity_scores(s_))


df__ = pd.DataFrame(frequency_word_.most_common(40), columns =['Harder Parts', 'Mentioned Word Frequency'])
df__
# Out:
# [('attack', 17), ('button', 9), ('press', 8), ('key', 7), ('hit', 6), ('tutorial', 6), ('attacks', 5), ('difference', 5), ('perfect', 5), ('timing', 5), ('strategy', 4), ('win', 4), ('exactly', 4), ('rhythm', 4), ('physical', 4), ('bar', 4), ('time', 4), ('players', 3), ('clear', 3), ('match', 3), ('defend', 3), ('spam', 3), ('health', 3), ('blocks', 3), ('block', 3), ('box', 3), ('move', 3), ('four', 3), ('None', 3), ('magic', 3), ('power', 3), ('keys', 3), ('white', 3), ('heal', 3), ('chose', 3), ('gameplay', 2), ('differences', 2), ('happens', 2), ('make', 2), ('correctly', 2)]
# {'neg': 0.19, 'neu': 0.606, 'pos': 0.204, 'compound': 0.8763}
#    Harder Parts  Mentioned Word Frequency
# 0        attack                        17
# 1        button                         9
# 2         press                         8
# 3           key                         7
# 4           hit                         6
# 5      tutorial                         6
# 6       attacks                         5
# 7    difference                         5
# 8       perfect                         5
# 9        timing                         5
# 10     strategy                         4
# 11          win                         4
# 12      exactly                         4
# 13       rhythm                         4
# 14     physical                         4
# 15          bar                         4
# 16         time                         4
# 17      players                         3
# 18        clear                         3
# 19        match                         3
# 20       defend                         3
# 21         spam                         3
# 22       health                         3
# 23       blocks                         3
# 24        block                         3
# 25          box                         3
# 26         move                         3
# 27         four                         3
# 28         None                         3
# 29        magic                         3
# 30        power                         3
# 31         keys                         3
# 32        white                         3
# 33         heal                         3
# 34        chose                         3
# 35     gameplay                         2
# 36  differences                         2
# 37      happens                         2
# 38         make                         2
# 39    correctly                         2

# %% [markdown]
# # How hard do you think the AI is?

# %%
import string
difficulty_AI=df_1.iloc[:, 4:5]
# difficulty_AI
result_difficulty_AI=difficulty_AI.to_string().strip().replace("\n", "")
result_difficulty_AI = ''.join([i for i in result_difficulty_AI if not i.isdigit()])
stop_words_ = set(stopwords.words('english'))
# print(stop_words)
word_tokens_ = word_tokenize(result_difficulty_AI)
filtered_sentence_ = [w for w in word_tokens_ if not w.lower() in stop_words_]
filtered_sentence_

#remove punctuations
words_without_punct = [''.join(letter for letter in i if letter not in string.punctuation) for i in filtered_sentence_]

processed_words_=[]
for i in words_without_punct:
    j = i.replace(' ','')
    processed_words_.append(j)

while("" in processed_words_) :
    processed_words_.remove("")
# print(processed_words_)


meaningless_words_=['What','could', 'I', 'think','There','D','s', 'Is','To','maybe','Maybe','This','s','Also','ca', 'nt','like'
                  'would','like','A','player','It','use','gets','s','All','The','levels','better','nt','seems','game','nt','It','I','An','even','eg','want','wanted']
for i in list(processed_words_): 
    if i in meaningless_words_:
        processed_words_.remove(i)
# print(processed_words_)


df = pd.DataFrame (processed_words_, columns = ['How hard do you think the AI is?'])
# print(df)
counts = df['How hard do you think the AI is?'].value_counts().to_dict()
print(counts)

frequency_word_ = nltk.FreqDist(processed_words_)
print(frequency_word_.most_common(40))

s_=" ".join(str(g) for g in processed_words_)
sia_ = SentimentIntensityAnalyzer()
sia_.polarity_scores(s_)

df__ = pd.DataFrame(frequency_word_.most_common(40), columns =['How hard do you think the AI is?', 'Mentioned Word Frequency'])
df__
# Out:
# {'AI': 31, 'Balanced': 29, 'Easy': 27, 'hard': 13, 'little': 11, 'Way': 9, 'easy': 8, 'balancing': 1}
# [('AI', 31), ('Balanced', 29), ('Easy', 27), ('hard', 13), ('little', 11), ('Way', 9), ('easy', 8), ('balancing', 1)]
#   How hard do you think the AI is?  Mentioned Word Frequency
# 0                               AI                        31
# 1                         Balanced                        29
# 2                             Easy                        27
# 3                             hard                        13
# 4                           little                        11
# 5                              Way                         9
# 6                             easy                         8
# 7                        balancing                         1

# %% [markdown]
# # What aspects of the game would you be interested in playing more of?

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
interesting_point= df_1.iloc[:, 5:6]
#convert dataframe to string
result_interesting_point=interesting_point.to_string().strip().replace("\n", "")
result_interesting_point = ''.join([i for i in result_interesting_point if not i.isdigit()])
# print(type(result))
# result_interesting_point

# %%
import string
stop_words_ = set(stopwords.words('english'))
# print(stop_words)
word_tokens_ = word_tokenize(result_interesting_point)
filtered_sentence_ = [w for w in word_tokens_ if not w.lower() in stop_words_]
# filtered_sentence_

# %%
#remove punctuations

words_without_punct = [''.join(letter for letter in i if letter not in string.punctuation) for i in filtered_sentence_]

processed_words_=[]
for i in words_without_punct:
    j = i.replace(' ','')
    processed_words_.append(j)

while("" in processed_words_) :
    processed_words_.remove("")
# print(processed_words_)

meaningless_words_=['What','would','could', 'I','d' ,'think','There','D','s', 'Is','To','maybe','Maybe','This','s','Also','ca', 'nt','like'
                  'would','like','im','A','different','player','It','use','gets','s','All','The','levels','better','nt','seems','game','nt','It','I','An','even','eg','want','wanted']
for i in list(processed_words_): 
    if i in meaningless_words_:
        processed_words_.remove(i)
# print(processed_words_)


df = pd.DataFrame (processed_words_, columns = ['What aspects of the game would you be interested in playing more of?'])
# print(df)
counts = df['What aspects of the game would you be interested in playing more of?'].value_counts().to_dict()
# print(counts)

frequency_word_ = nltk.FreqDist(processed_words_)
print(frequency_word_.most_common(50))

s_=" ".join(str(g) for g in processed_words_)
sia_ = SentimentIntensityAnalyzer()
print(sia_.polarity_scores(s_))


df__ = pd.DataFrame(frequency_word_.most_common(50), columns =['Interesting Aspects', 'Mentioned Word Frequency'])
df__
# Out:
# [('music', 11), ('play', 11), ('AI', 8), ('interested', 7), ('attack', 7), ('combos', 6), ('interesting', 5), ('part', 5), ('songs', 5), ('beats', 5), ('fun', 4), ('strategy', 4), ('shield', 4), ('power', 4), ('fighting', 3), ('really', 3), ('rhythm', 3), ('combination', 3), ('fast', 3), ('rhythms', 3), ('physical', 3), ('skills', 3), ('song', 3), ('also', 3), ('heal', 3), ('playing', 2), ('much', 2), ('typing', 2), ('aspect', 2), ('way', 2), ('make', 2), ('friend', 2), ('system', 2), ('attacking', 2), ('combo', 2), ('something', 2), ('instead', 2), ('elements', 2), ('beat', 2), ('help', 2), ('keys', 2), ('trying', 2), ('skill', 2), ('types', 2), ('players', 2), ('love', 2), ('magic', 2), ('type', 2), ('blocks', 2), ('cool', 2)]
# {'neg': 0.147, 'neu': 0.495, 'pos': 0.358, 'compound': 0.9984}
#    Interesting Aspects  Mentioned Word Frequency
# 0                music                        11
# 1                 play                        11
# 2                   AI                         8
# 3           interested                         7
# 4               attack                         7
# 5               combos                         6
# 6          interesting                         5
# 7                 part                         5
# 8                songs                         5
# 9                beats                         5
# 10                 fun                         4
# 11            strategy                         4
# 12              shield                         4
# 13               power                         4
# 14            fighting                         3
# 15              really                         3
# 16              rhythm                         3
# 17         combination                         3
# 18                fast                         3
# 19             rhythms                         3
# 20            physical                         3
# 21              skills                         3
# 22                song                         3
# 23                also                         3
# 24                heal                         3
# 25             playing                         2
# 26                much                         2
# 27              typing                         2
# 28              aspect                         2
# 29                 way                         2
# 30                make                         2
# 31              friend                         2
# 32              system                         2
# 33           attacking                         2
# 34               combo                         2
# 35           something                         2
# 36             instead                         2
# 37            elements                         2
# 38                beat                         2
# 39                help                         2
# 40                keys                         2
# 41              trying                         2
# 42               skill                         2
# 43               types                         2
# 44             players                         2
# 45                love                         2
# 46               magic                         2
# 47                type                         2
# 48              blocks                         2
# 49                cool                         2

# %% [markdown]
# # What parts of the game could be improved - and why?

# %%
improvoing_why= df_1.iloc[:, 6:7]
result=improvoing_why.to_string().strip().replace("\n", "")
result = ''.join([i for i in result if not i.isdigit()])
# print(type(result))
# result

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import pandas as pd
from nltk.sentiment import SentimentIntensityAnalyzer
import string

stop_words = set(stopwords.words('english'))
# print(stop_words)
  
word_tokens = word_tokenize(result)
# word_tokens  
filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
# filtered_sentence  
# filtered_sentence = []
  
# for w in word_tokens:
#     if w not in stop_words:
#         filtered_sentence.append(w)
# #remove punctuations

words = [''.join(letter for letter in i if letter not in string.punctuation) for i in filtered_sentence]
# words
processed_words_=[]
for i in words:
    j = i.replace(' ','')
    processed_words_.append(j)
# processed_words

while("" in processed_words_) :
    processed_words_.remove("")
# print(processed_words_)

meaningless_words_=['What','would','could', 'I','d' ,'think','There','D','s', 'Is','To','maybe','Maybe','This','s','Also','ca', 'nt','like'
                  'would','like','different','im','A','player','ex','It','use','gets','s','All','The','levels','better','nt','seems','game','nt','It','I','An','even','eg','want','wanted']
for i in list(processed_words_): 
    if i in meaningless_words_:
        processed_words_.remove(i)
# print(processed_words_)


df = pd.DataFrame (processed_words_, columns = ['What parts of the game could be improved - and why?'])
# print(df)
counts = df['What parts of the game could be improved - and why?'].value_counts().to_dict()
# print(counts)

frequency_word_ = nltk.FreqDist(processed_words_)
print(frequency_word_.most_common(50))

s_=" ".join(str(g) for g in processed_words_)
sia_ = SentimentIntensityAnalyzer()
print(sia_.polarity_scores(s_))

df__ = pd.DataFrame(frequency_word_.most_common(50), columns =['What parts of the game could be improved & why?', 'Mentioned Word Frequency'])
df__
# Out:
# [('attack', 11), ('players', 10), ('tutorial', 10), ('add', 9), ('hit', 9), ('notes', 8), ('two', 8), ('perfect', 7), ('physical', 6), ('time', 6), ('hard', 6), ('make', 6), ('magic', 6), ('beats', 6), ('music', 5), ('strategy', 5), ('skills', 5), ('AI', 5), ('fun', 5), ('rhythm', 5), ('good', 5), ('understand', 5), ('win', 5), ('etc', 4), ('keys', 4), ('animations', 4), ('buttons', 4), ('playing', 4), ('key', 4), ('color', 4), ('need', 4), ('button', 4), ('attacks', 4), ('improved', 3), ('effects', 3), ('adding', 3), ('away', 3), ('instead', 3), ('hitting', 3), ('really', 3), ('much', 3), ('match', 3), ('characters', 3), ('help', 3), ('get', 3), ('ability', 3), ('penalty', 3), ('miss', 3), ('pressing', 3), ('first', 3)]
# {'neg': 0.173, 'neu': 0.572, 'pos': 0.254, 'compound': 0.9978}
#    What parts of the game could be improved & why?  Mentioned Word Frequency
# 0                                           attack                        11
# 1                                          players                        10
# 2                                         tutorial                        10
# 3                                              add                         9
# 4                                              hit                         9
# 5                                            notes                         8
# 6                                              two                         8
# 7                                          perfect                         7
# 8                                         physical                         6
# 9                                             time                         6
# 10                                            hard                         6
# 11                                            make                         6
# 12                                           magic                         6
# 13                                           beats                         6
# 14                                           music                         5
# 15                                        strategy                         5
# 16                                          skills                         5
# 17                                              AI                         5
# 18                                             fun                         5
# 19                                          rhythm                         5
# 20                                            good                         5
# 21                                      understand                         5
# 22                                             win                         5
# 23                                             etc                         4
# 24                                            keys                         4
# 25                                      animations                         4
# 26                                         buttons                         4
# 27                                         playing                         4
# 28                                             key                         4
# 29                                           color                         4
# 30                                            need                         4
# 31                                          button                         4
# 32                                         attacks                         4
# 33                                        improved                         3
# 34                                         effects                         3
# 35                                          adding                         3
# 36                                            away                         3
# 37                                         instead                         3
# 38                                         hitting                         3
# 39                                          really                         3
# 40                                            much                         3
# 41                                           match                         3
# 42                                      characters                         3
# 43                                            help                         3
# 44                                             get                         3
# 45                                         ability                         3
# 46                                         penalty                         3
# 47                                            miss                         3
# 48                                        pressing                         3
# 49                                           first                         3
